# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
df=pd.read_excel("XiaomiRawdata.xlsx")
df.head()
# Out:
#    Customer       Day            Browser  No. of Clicks  Pages Viewed  \
# 0         1    Monday             Chrome             13             4
# 1         2  Saturday             Chrome             15             5
# 2         3    Monday  Internet Explorer             20             6
# 3         4    Monday             Chrome             42             6
# 4         5  Saturday  Internet Explorer             20             6
#
#    Time (min)  Amount Spent (Rs.)
# 0         8.5              2668.0
# 1        16.9              3469.0
# 2         7.3              5215.0
# 3        30.1             10423.0
# 4        13.3              5404.0

# %% [markdown]
# # Boxplot
# - Box plot is commonly used to study the descriptive statistics of the column.
# - Mostly used to plt the outliers in the column.

# %%
plt.boxplot(df["Amount Spent (Rs.)"])
plt.show()

# %%
df["Amount Spent (Rs.)"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(df["Time (min)"])
plt.show()

# %%
plt.boxplot(df["Pages Viewed"])
plt.show()

# %%
plt.boxplot(df["No. of Clicks"])
plt.show()

# %%
sns.boxplot(df["No. of Clicks"])
# Out:
# <AxesSubplot:xlabel='No. of Clicks'>

# %% [markdown]
# # Scatter Plot
# - used to see the correlation between two continous variables

# %%
plt.scatter(df["No. of Clicks"],df["Time (min)"])
plt.show()

# %%
sns.scatterplot(df["No. of Clicks"],df["Time (min)"])
# Out:
# <AxesSubplot:xlabel='No. of Clicks', ylabel='Time (min)'>

# %% [markdown]
# # Heatmap
# - used to check/text multicollinearity in the data

# %% [markdown]
# # Homework
# - Multi collinearity
# - Correlation
# - Covariance
# - Multi collinear

# %%
df.corr()
# Out:
#                     Customer  No. of Clicks  Pages Viewed  Time (min)  \
# Customer            1.000000       0.002474      0.000821   -0.001407
# No. of Clicks       0.002474       1.000000      0.566934    0.516365
# Pages Viewed        0.000821       0.566934      1.000000    0.595568
# Time (min)         -0.001407       0.516365      0.595568    1.000000
# Amount Spent (Rs.)  0.002682       0.903248      0.723667    0.580048
#
#                     Amount Spent (Rs.)
# Customer                      0.002682
# No. of Clicks                 0.903248
# Pages Viewed                  0.723667
# Time (min)                    0.580048
# Amount Spent (Rs.)            1.000000

# %%
sns.scatterplot(df["No. of Clicks"],df["No. of Clicks"])
# Out:
# <AxesSubplot:xlabel='No. of Clicks', ylabel='No. of Clicks'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Line Chart
# - used to show relationship between two data x and y on different axis

# %%
plt.plot(df["Amount Spent (Rs.)"],df["No. of Clicks"])
#plt.plot(df["No. of Clicks"])
plt.title("Scatter Plot")
plt.xlabel("Amount")
plt.ylabel("Pages Viewed")
plt.show()

# %%
sns.lineplot(df["No. of Clicks"],df["Amount Spent (Rs.)"])
# Out:
# <AxesSubplot:xlabel='No. of Clicks', ylabel='Amount Spent (Rs.)'>

# %%
#plt.figure(figsize=(8,5))
#sns.lineplot(df.drop(["Day","Browser"], axis = 1))
